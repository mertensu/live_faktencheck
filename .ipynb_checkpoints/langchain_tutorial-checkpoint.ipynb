# %%
import getpass
import os

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = getpass.getpass()
# Out:
#  ········

# %%
if not os.environ.get("MISTRAL_API_KEY"):
  os.environ["MISTRAL_API_KEY"] = getpass.getpass("Enter API key for Mistral AI: ")

from langchain.chat_models import init_chat_model

model = init_chat_model("mistral-large-latest", model_provider="mistralai")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from English into Italian"),
    HumanMessage("hi!"),
]

model.invoke(messages)
# Out:
# AIMessage(content='Ciao!\n\nHere are a few other translations for "hi" in Italian:\n\n* Salve! (formal)\n* Ehi! (informal)\n* Ciao a tutti! ( Hi everyone!)\n* Buongiorno! (Good morning! )\n* Buon pomeriggio! (Good afternoon!)\n* Buonasera! (Good evening!)\n* Buonanotte! (Goodnight!)', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 15, 'total_tokens': 112, 'completion_tokens': 97}, 'model': 'mistral-large-latest', 'finish_reason': 'stop'}, id='run-99a1d701-14e1-424d-9ce2-24a51f1f69e7-0', usage_metadata={'input_tokens': 15, 'output_tokens': 97, 'total_tokens': 112})

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "Italian", "text": "hi!"})

prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into Italian', additional_kwargs={}, response_metadata={}), HumanMessage(content='hi!', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into Italian', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='hi!', additional_kwargs={}, response_metadata={})]

# %%
response = model.invoke(prompt)
print(response.content)
# Out:
# Ciao!
#
# ( "Hi!" in Italian is "Ciao!")
#
# Here are a few more translations for greetings:
#
# * Hello! = Salve!
# * Good morning! = Buongiorno!
# * Good evening! = Buonasera!
# * Good night! = Buonanotte!
# * Goodbye! = Arrivederci!
# * See you soon! = A presto!
# * Good afternoon! = Buon pomeriggio! (It's less common than the other greetings, but you might still hear it)
